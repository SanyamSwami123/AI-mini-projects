# %% [raw]
# Read the preprocessed tmdb_dataset that you have created.

# %% [markdown]
# ## Q 1.
# #### How many movies are made in 'English' language ?
# #### Find this out using three diffrent methods - `sum`, `len` and `shape`.

# %% [markdown]
# ## Q 2.
# #### Create a pandas series of engish movie titles .

# %% [markdown]
# ## Q 3.
# #### How many movies are made in each language ?

# %% [markdown]
# ## Q 4.
# #### How many languages are there in which only one movie is made ?

# %% [markdown]
# ## Q 5.
# #### Which movie gathered maximum revenue and what is the revenue amount ?

# %% [markdown]
# ## Q 6.
# #### Find movie with least vote_count.

# %% [markdown]
# ## Q 7.
# #### Sort movies in ascending order of budget .

# %% [markdown]
# ## Q 8.
# #### What is the difference between outputs of following two codes.

# %%
# df.sort_values('popularity').head(5)
# df.popularity.sort_values()

# %% [markdown]
# ## Q 9.
# #### Find out average revenue generated by movies in each language .

# %% [markdown]
# ## Q 10.
# #### Check the datatypes of all the columns and select only those columns with 'float' values.

# %% [markdown]
# ## Q 11.
# #### What is the maximum and minimum runtime of movie ?

# %% [markdown]
# ## Q 12.
# #### What are the first three movies with largest vote_count ?

# %% [markdown]
# ## Q 13.
# #### For each type of value in `status` column find mean of `vote_count` and `budget` and `revenue`.
